# %%
import pandas as pd

movies = pd.read_csv(r"C:\Users\ivann\OneDrive\Documents\~Personal Development (Resumes, Cover Letters, etc)\Python\Data Sets\P4-Movie-Ratings.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','CriticRating', 'AudienceRating',
                 'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
#This function tells us what type of data we have within our database
#The first step of data science is to prepare your data. 
#This includes changing your data types to a data type that is representative of the information you are using
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
#Summary of our data
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
#Define the data in the Film category as 'category' data rather than an object
movies['Film'] = movies['Film'].astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
#How to check categories
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']

# %%
#Working with Joint plots
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Jointplots

# %%
j = sns.jointplot(data=movies, x='CriticRating',y='AudienceRating', color='Green', kind = "hex")

# %%
#KDE Plots

# %%
#Violin Plots

# %%
z = sns.violinplot(data=movies, x='Genre',y='CriticRating')

# %%
w = sns.boxplot(data=movies, x='Genre',y='CriticRating')

# %%
h1 = sns.violinplot(data=movies[movies.Genre == 'Horror'], x='Year',y='CriticRating')

# %%
h2 = sns.boxplot(data=movies[movies.Genre == 'Horror'], x='Year',y='CriticRating')

# %%
#Creating a Facet Grid

# %%
g2 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g2= g2.map(plt.scatter, 'CriticRating' , 'AudienceRating')

# %%
#We can populate with any type of chart
g1 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g1= g1.map(plt.hist, 'BudgetMillions')

# %%
#Back to our scatter plot:
g2 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor ='black')
g2= g2.map(plt.scatter, 'CriticRating' , 'AudienceRating', **kws)
g2.set(xlim=(0,100), ylim=(1,100)) #ths sets the graph boundaries
#graphing a line on each of the facet charts
for ax in g2.axes.flat:
    ax.plot((0,100),(0,100),c='gray', ls="--")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-d78bac3c4973> in <module>
#       1 #Back to our scatter plot:
# ----> 2 g2 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
#       3 kws = dict(s=50, linewidth=0.5, edgecolor ='black')
#       4 g2= g2.map(plt.scatter, 'CriticRating' , 'AudienceRating', **kws)
#       5 g2.set(xlim=(0,100), ylim=(1,100)) #ths sets the graph boundaries
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
#Back to our scatter plot:
g2 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor ='black')
g2= g2.map(plt.scatter, 'CriticRating' , 'AudienceRating', **kws)
g2.set(xlim=(0,100), ylim=(1,100)) #ths sets the graph boundaries
#graphing a line on each of the facet charts
for ax in g2.axes.flat:
    ax.plot((0,100),(0,100),c='gray', ls="--")
g2.add_legend()
